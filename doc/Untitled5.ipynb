# %%
import pandas as pd

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('max_colwidth',100)#设置数据展示宽度
#同时显示多行
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 


from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
import sys
# sys.path
# Out:
# ['/Users/xiayiming',
#  '/Users/xiayiming/opt/anaconda3/lib/python38.zip',
#  '/Users/xiayiming/opt/anaconda3/lib/python3.8',
#  '/Users/xiayiming/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/Users/xiayiming/opt/anaconda3/lib/python3.8/site-packages',
#  '/Users/xiayiming/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/Users/xiayiming/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/xiayiming/.ipython',
#  '/Users/xiayiming/Documents/GitHub/spring-2022-prj1-yimingxia-0414',
#  '/Users/xiayiming/Documents/GitHub/spring-2022-prj1-yimingxia-0414/lib']

# %%
df = pd.read_csv('../data/philosophy_data.csv',encoding="UTF-8")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360808 entries, 0 to 360807
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   title                      360808 non-null  object
#  1   author                     360808 non-null  object
#  2   school                     360808 non-null  object
#  3   sentence_spacy             360808 non-null  object
#  4   sentence_str               360808 non-null  object
#  5   original_publication_date  360808 non-null  int64
#  6   corpus_edition_date        360808 non-null  int64
#  7   sentence_length            360808 non-null  int64
#  8   sentence_lowered           360808 non-null  object
#  9   tokenized_txt              360808 non-null  object
#  10  lemmatized_str             360808 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 30.3+ MB

# %%
df['title'].nunique()
df['author'].nunique()
df['school'].nunique()
# Out:
# 59
# 36
# 13

# %%
df=df[360000:360100]

# %%
df["lemmatized_str"] = df["tokenized_txt"].apply(
    lambda row: clean_sentence(ast.literal_eval(row))
)

# %%
df
# Out:
#                          title author    school  \
# 360000  Women, Race, And Class  Davis  feminism
# 360001  Women, Race, And Class  Davis  feminism
# 360002  Women, Race, And Class  Davis  feminism
# 360003  Women, Race, And Class  Davis  feminism
# 360004  Women, Race, And Class  Davis  feminism
# 360005  Women, Race, And Class  Davis  feminism
# 360006  Women, Race, And Class  Davis  feminism
# 360007  Women, Race, And Class  Davis  feminism
# 360008  Women, Race, And Class  Davis  feminism
# 360009  Women, Race, And Class  Davis  feminism
# 360010  Women, Race, And Class  Davis  feminism
# 360011  Women, Race, And Class  Davis  feminism
# 360012  Women, Race, And Class  Davis  feminism
# 360013  Women, Race, And Class  Davis  feminism
# 360014  Women, Race, And Class  Davis  feminism
# 360015  Women, Race, And Class  Davis  feminism
# 360016  Women, Race, And Class  Davis  feminism
# 360017  Women, Race, And Class  Davis  feminism
# ...

# %%
# df.groupby('school').get_group('communism').head()
# Out:
#           title author     school  \
# 289938  Capital   Marx  communism
# 289939  Capital   Marx  communism
# 289940  Capital   Marx  communism
# 289941  Capital   Marx  communism
# 289942  Capital   Marx  communism
#
#                                                                                              sentence_spacy  \
# 289938   The wealth of those societies in which the capitalist mode of production prevails, presents its...
# 289939                             Our investigation must therefore begin with the analysis of a commodity.
# 289940  A commodity is, in the first place, an object outside us, a thing that by its properties satisfi...
# 289941  The nature of such wants, whether, for instance, they spring from the stomach or from fancy, mak...
# 289942  Neither are we here concerned to know how the object satisfies these wants, whether directly as ...
#
#                                                                                                sentence_str  \
# ...

# %%
# df.groupby(by=['school','author','title'])['title'].count()
# Out:
# school           author           title
# analytic         Kripke           Naming And Necessity                                        2681
#                                   Philosophical Troubles                                      9798
#                  Lewis            Lewis - Papers                                             13120
#                  Moore            Philosophical Studies                                       3668
#                  Popper           The Logic Of Scientific Discovery                           4678
#                  Quine            Quintessence                                                7373
#                  Russell          The Analysis Of Mind                                        3513
#                                   The Problems Of Philosophy                                  1560
#                  Wittgenstein     On Certainty                                                1984
# ...
